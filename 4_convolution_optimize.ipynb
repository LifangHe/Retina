# %%
import timeit
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory

image_size = 28
num_labels = 10
num_channels = 1

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels

train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)

print('Training set', train_dataset.shape, train_labels.shape, type(train_dataset), type(train_labels))
print('Validation set', valid_dataset.shape, valid_labels.shape, type(valid_dataset), type(valid_labels))
print('Test set', test_dataset.shape, test_labels.shape, type(test_dataset), type(test_labels))
print 'train_labels.shape[0]', train_labels.shape[0]
# Out:
# ('Training set', (200000, 28, 28, 1), (200000, 10), <type 'numpy.ndarray'>, <type 'numpy.ndarray'>)
# ('Validation set', (10000, 28, 28, 1), (10000, 10), <type 'numpy.ndarray'>, <type 'numpy.ndarray'>)
# ('Test set', (18724, 28, 28, 1), (18724, 10), <type 'numpy.ndarray'>, <type 'numpy.ndarray'>)
# train_labels.shape[0] 200000

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])
print "defined accuracy function"
# Out:
# defined accuracy function

# %%
# dont change this model it is here for reference
batch_size = 16
patch_size = 3
depth = 32
num_hidden = 512
L2_reg_const = 0.5e-3

graph = tf.Graph()

with graph.as_default():

  dropout_p = tf.placeholder(tf.float32)
  
  # Input data.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)

  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))

  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))

  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
  layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

  L2_reg = (tf.nn.l2_loss(layer1_weights) + tf.nn.l2_loss(layer2_weights) 
    + tf.nn.l2_loss(layer3_weights) + tf.nn.l2_loss(layer4_weights))  

  # Model.
  def model(data, dropout_p, verbose = False):
    
    conv1 = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    
    hidden1 = tf.nn.relu(conv1 + layer1_biases)
    
    pooled = tf.nn.max_pool(hidden1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    
    conv2 = tf.nn.conv2d(pooled, layer2_weights, [1, 1, 1, 1], padding='SAME')
    
    hidden2 = tf.nn.relu(conv2 + layer2_biases)
    
    shape = hidden2.get_shape().as_list() 
       
    reshape2 = tf.reshape(hidden2, [shape[0], shape[1] * shape[2] * shape[3]])
    
    hidden3 = tf.nn.relu(tf.matmul(reshape2, layer3_weights) + layer3_biases)
    
    layer_dropout3 = tf.nn.dropout(hidden3, dropout_p)
    
    final_output = tf.matmul(layer_dropout3, layer4_weights) + layer4_biases
    if verbose == True:
        print 'data shape', data.get_shape().as_list() # [16, 28, 28, 1]
        print 'first nonlinearity with bias', hidden1.get_shape().as_list()
        print 'after pooling', pooled.get_shape().as_list()
        print 'second convolution output shape', shape
    
    return final_output
  
  # Training computation.
  logits = model(tf_train_dataset, dropout_p)
  loss = (tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels)) + L2_reg_const*L2_reg )
    
  # Optimizer.

  global_step = tf.Variable(0, trainable=False)
  starter_learning_rate = 0.1
  learning_rate = tf.train.exponential_decay(starter_learning_rate,global_step,100,0.99,staircase=True)

  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)

  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(model(tf_train_dataset, dropout_p, verbose = True))
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset, dropout_p = 1.0))
  test_prediction = tf.nn.softmax(model(tf_test_dataset, dropout_p = 1.0))

print 'Nodes created over computation graph'

num_steps = 24001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  start_time = timeit.default_timer()

  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    
    feed_dict_train = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, dropout_p: 0.5}
        
    _, training_loss, LR = session.run([optimizer, loss, learning_rate], feed_dict=feed_dict_train)
    
    feed_train_predict = {tf_train_dataset : batch_data, dropout_p: 1}
        
    batch_predictions = session.run(train_prediction, feed_dict=feed_train_predict)
    
    if (step % 1000 == 0): 
       print 'learning rate',LR
       print("Minibatch training set loss at step %d: %f" % (step, training_loss))
       print("Minibatch training set accuracy: %.1f%%" % accuracy(batch_predictions, batch_labels))
       print("Validation accuracy: %.1f%%" % accuracy(valid_prediction.eval(), valid_labels))
    
  end_time = timeit.default_timer()
  #feed_test_predict = {tf_test_dataset : test_dataset, dropout_p: 1}
  #test_predictions = session.run(test_prediction, feed_dict=feed_test_predict)
  print("Finished: Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
  print('ran for %.2fm' % ((end_time - start_time) / 60.))

# %%
batch_size = 16
patch_size = 3
depth = 24
num_hidden = 72
L2_reg_const = 0.5e-3

graph = tf.Graph()

with graph.as_default():

  dropout_p = tf.placeholder(tf.float32)
  
  # Input data.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)

  layer0_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer0_biases = tf.Variable(tf.zeros([depth]))

  layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))

  layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))

  layer3_weights = tf.Variable(tf.truncated_normal([12*12* depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
  layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_hidden], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
  layer5_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
  layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

  L2_reg = (tf.nn.l2_loss(layer0_weights) +
            + tf.nn.l2_loss(layer1_weights) + tf.nn.l2_loss(layer2_weights)
            + tf.nn.l2_loss(layer3_weights) + tf.nn.l2_loss(layer4_weights) 
            + tf.nn.l2_loss(layer5_weights))  

  # Model.
  def model(data, dropout_p, verbose = False):
    
    conv0 = tf.nn.relu((tf.nn.conv2d(data,layer0_weights,[1, 1, 1, 1],padding='SAME'))+layer0_biases)
    
    conv1 = tf.nn.relu((tf.nn.conv2d(conv0,layer1_weights,[1, 1, 1, 1],padding='VALID'))+layer1_biases)
    
    conv2 = tf.nn.relu((tf.nn.conv2d(conv1, layer2_weights, [1, 2, 2, 1], padding='VALID')) + layer2_biases)
    
    shape = conv2.get_shape().as_list() 
       
    reshape2 = tf.reshape(conv2, [shape[0], shape[1] * shape[2] * shape[3]])
    
    hidden3 = tf.nn.relu(tf.matmul(reshape2, layer3_weights) + layer3_biases)
    
    layer_dropout3 = tf.nn.dropout(hidden3, dropout_p)
    
    hidden4 = tf.nn.relu(tf.matmul(layer_dropout3, layer4_weights) + layer4_biases)
    
    final_output = tf.matmul(hidden4, layer5_weights) + layer5_biases
    
    if verbose == True:
        print 'data shape', data.get_shape().as_list() # [16, 28, 28, 1]
        print 'conv0', conv0.get_shape().as_list()
        print 'conv1', conv1.get_shape().as_list()
        print 'conv2', conv2.get_shape().as_list()
    
    return final_output
  
  # Training computation.
  logits = model(tf_train_dataset, dropout_p)
  loss = (tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels)) + L2_reg_const*L2_reg )
    
  # Optimizer.

  global_step = tf.Variable(0, trainable=False)
  starter_learning_rate = 0.1
  learning_rate = tf.train.exponential_decay(starter_learning_rate,global_step,100,0.99,staircase=True)

  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)

  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(model(tf_train_dataset, dropout_p, verbose = True))
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset, dropout_p = 1.0))
  test_prediction = tf.nn.softmax(model(tf_test_dataset, dropout_p = 1.0))

print 'Nodes created over computation graph'
# Out:
# data shape [16, 28, 28, 1]
# conv0 [16, 28, 28, 24]
# conv1 [16, 26, 26, 24]
# conv2 [16, 12, 12, 24]
# Nodes created over computation graph

# %%
num_steps = 30001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  start_time = timeit.default_timer()

  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    
    feed_dict_train = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, dropout_p: 0.5}
        
    _, training_loss, LR = session.run([optimizer, loss, learning_rate], feed_dict=feed_dict_train)
    
    feed_train_predict = {tf_train_dataset : batch_data, dropout_p: 1}
        
    batch_predictions = session.run(train_prediction, feed_dict=feed_train_predict)
    
    if (step % 1000 == 0): 
       print 'learning rate',LR
       print("Minibatch training set loss at step %d: %f" % (step, training_loss))
       print("Minibatch training set accuracy: %.1f%%" % accuracy(batch_predictions, batch_labels))
       print("Validation accuracy: %.1f%%" % accuracy(valid_prediction.eval(), valid_labels))
    
  end_time = timeit.default_timer()
  #feed_test_predict = {tf_test_dataset : test_dataset, dropout_p: 1}
  #test_predictions = session.run(test_prediction, feed_dict=feed_test_predict)
  print("Finished: Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
  print('ran for %.2fm' % ((end_time - start_time) / 60.))
# Out:
# Initialized
# learning rate 0.1
# Minibatch training set loss at step 0: 4.869905
# Minibatch training set accuracy: 18.8%
# Validation accuracy: 10.1%
# learning rate 0.0904382
# Minibatch training set loss at step 1000: 1.482539
# Minibatch training set accuracy: 75.0%
# Validation accuracy: 76.8%
# learning rate 0.0817907
# Minibatch training set loss at step 2000: 2.204941
# Minibatch training set accuracy: 62.5%
# Validation accuracy: 80.2%
# learning rate 0.0739701
# Minibatch training set loss at step 3000: 0.992172
# Minibatch training set accuracy: 93.8%
# Validation accuracy: 82.3%
# learning rate 0.0668972
# Minibatch training set loss at step 4000: 1.141256
# Minibatch training set accuracy: 81.2%
# Validation accuracy: 83.6%
# learning rate 0.0605006
# Minibatch training set loss at step 5000: 1.032388
# Minibatch training set accuracy: 81.2%
# Validation accuracy: 83.9%
# learning rate 0.0547157
# Minibatch training set loss at step 6000: 1.292550
# Minibatch training set accuracy: 75.0%
# Validation accuracy: 84.8%
# learning rate 0.0494839
# Minibatch training set loss at step 7000: 0.824868
# Minibatch training set accuracy: 93.8%
# Validation accuracy: 84.7%
# learning rate 0.0447524
# Minibatch training set loss at step 8000: 0.531792
# Minibatch training set accuracy: 100.0%
# Validation accuracy: 85.2%
# learning rate 0.0404732
# Minibatch training set loss at step 9000: 0.783736
# Minibatch training set accuracy: 87.5%
# Validation accuracy: 85.8%
# learning rate 0.0366033
# Minibatch training set loss at step 10000: 1.049343
# Minibatch training set accuracy: 87.5%
# Validation accuracy: 85.8%
# learning rate 0.0331033
# Minibatch training set loss at step 11000: 0.466973
# Minibatch training set accuracy: 93.8%
# Validation accuracy: 86.0%
# learning rate 0.0299381
# Minibatch training set loss at step 12000: 0.500662
# Minibatch training set accuracy: 100.0%
# Validation accuracy: 86.4%
# learning rate 0.0270755
# Minibatch training set loss at step 13000: 0.494114
# Minibatch training set accuracy: 93.8%
# Validation accuracy: 86.3%
# learning rate 0.0244866
# Minibatch training set loss at step 14000: 0.923948
# Minibatch training set accuracy: 87.5%
# Validation accuracy: 86.5%
# learning rate 0.0221452
# Minibatch training set loss at step 15000: 0.714640
# Minibatch training set accuracy: 93.8%
# Validation accuracy: 86.8%
# learning rate 0.0200277
# Minibatch training set loss at step 16000: 0.741492
# Minibatch training set accuracy: 93.8%
# Validation accuracy: 86.7%
# learning rate 0.0181127
# Minibatch training set loss at step 17000: 0.533449
# Minibatch training set accuracy: 100.0%
# Validation accuracy: 86.9%
# learning rate 0.0163808
# Minibatch training set loss at step 18000: 1.060677
# Minibatch training set accuracy: 75.0%
# Validation accuracy: 87.4%
# learning rate 0.0148145
# Minibatch training set loss at step 19000: 0.495878
# Minibatch training set accuracy: 100.0%
# Validation accuracy: 87.5%
# learning rate 0.013398
# Minibatch training set loss at step 20000: 0.777629
# Minibatch training set accuracy: 81.2%
# Validation accuracy: 87.6%
# learning rate 0.0121169
# Minibatch training set loss at step 21000: 0.453655
# Minibatch training set accuracy: 93.8%
# Validation accuracy: 87.5%
# learning rate 0.0109583
# Minibatch training set loss at step 22000: 0.552313
# Minibatch training set accuracy: 100.0%
# Validation accuracy: 87.6%
# learning rate 0.0099105
# Minibatch training set loss at step 23000: 0.727837
# Minibatch training set accuracy: 87.5%
# Validation accuracy: 87.7%
# learning rate 0.00896288
# Minibatch training set loss at step 24000: 0.522559
# Minibatch training set accuracy: 100.0%
# Validation accuracy: 87.9%
# learning rate 0.00810587
# Minibatch training set loss at step 25000: 0.746535
# Minibatch training set accuracy: 93.8%
# Validation accuracy: 88.1%
# learning rate 0.00733081
# Minibatch training set loss at step 26000: 0.268843
# Minibatch training set accuracy: 100.0%
# Validation accuracy: 88.1%
# learning rate 0.00662985
# Minibatch training set loss at step 27000: 0.620071
# Minibatch training set accuracy: 93.8%
# Validation accuracy: 88.2%
# learning rate 0.00599592
# Minibatch training set loss at step 28000: 1.248820
# Minibatch training set accuracy: 81.2%
# Validation accuracy: 88.2%
# learning rate 0.0054226
# Minibatch training set loss at step 29000: 0.570102
# Minibatch training set accuracy: 93.8%
# Validation accuracy: 88.3%
# learning rate 0.0049041
# Minibatch training set loss at step 30000: 0.390191
# Minibatch training set accuracy: 100.0%
# Validation accuracy: 88.2%
# Finished: Test accuracy: 94.1%
# ran for 31.60m
