# %%
import numpy as np
import h5py
import pickle
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import urllib
import cv2

# %%
i=1
with h5py.File('num_arr.h5', 'a') as na:
        onehot = np.array(na.get('onehot'+str(i)))
        arr = np.array(na.get('arr'+str(i)))
        row,_ = onehot.shape
        for j in range(row):
            if np.argmax(onehot[j]) == 3:
                print j
# Out:
# 32
# 33
# 54
# 55
# 154
# 155
# 354
# 355
# 406
# 407
# 446
# 447
# 452
# 453

# %%
# %matplotlib inline
plt.imshow(arr[55])

# %%
for i in range(83):
    with h5py.File('num_arr.h5', 'a') as na:
            onehot = np.array(na.get('onehot'+str(i)))
            arr = np.array(na.get('arr'+str(i)))
            print onehot.shape, arr.shape
# Out:
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (499, 4) (499, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (500, 4) (500, 450, 600, 3)
# (347, 4) (423, 450, 600, 3)
# (203, 4) (351, 450, 600, 3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-5c8401838a46> in <module>()
#       2     with h5py.File('num_arr.h5', 'a') as na:
#       3             onehot = np.array(na.get('onehot'+str(i)))
# ----> 4             arr = np.array(na.get('arr'+str(i)))
#       5             print onehot.shape, arr.shape
#       6
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/Users/travis/build/MacPython/h5py-wheels/h5py/h5py/_objects.c:2458)()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/Users/travis/build/MacPython/h5py-wheels/h5py/h5py/_objects.c:2415)()
#
# //anaconda/envs/python27/lib/python2.7/site-packages/h5py/_hl/dataset.pyc in __array__(self, dtype)
#     644             return arr
#     645
# --> 646         self.read_direct(arr)
#     647         return arr
#     648
#
# //anaconda/envs/python27/lib/python2.7/site-packages/h5py/_hl/dataset.pyc in read_direct(self, dest, source_sel, dest_sel)
#     607
#     608             for mspace in dest_sel.broadcast(source_sel.mshape):
# --> 609                 self.id.read(mspace, fspace, dest)
#     610
#     611     def write_direct(self, source, source_sel=None, dest_sel=None):
#
# KeyboardInterrupt:
